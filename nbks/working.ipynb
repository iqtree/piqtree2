# %%
# parse yaml
from cogent3 import load_aligned_seqs
from piqtree2 import build_tree
from piqtree2.model import DnaModel

aln = load_aligned_seqs("../tests/data/example.fasta").take_seqs(["Human", "Chimpanzee", "Rhesus", "Mouse"])

tree = build_tree(aln, DnaModel.HKY)
# Out:
# Seed: 1763811343
# IQ-TREE version 2.3.5.lib COVID-edition for Linux 64-bit built Aug  8 2024
# Developed by Bui Quang Minh, James Barbetti, Nguyen Lam Tung,
# Olga Chernomor, Heiko Schmidt, Dominik Schrempf, Michael Woodhams, Ly Trong Nhan.
#
# Host:    9171405acd0c (SSE4.2, 11 GB RAM)
# Time:    Mon Aug 12 04:05:30 2024
# Kernel:  SSE2
#
# Alignment most likely contains DNA/RNA sequences
# WARNING: 162 sites contain only gaps or ambiguous characters.
# Alignment has 4 sequences with 3009 columns, 87 distinct patterns
# 38 parsimony-informative, 725 singleton sites, 2246 constant sites
#             Gap/Ambiguity  Composition  p-value
# Analyzing sequences: done in 0.000118017 secs using 92.36% CPU
#    1  Human         5.68%    passed     29.79%
#    2  Chimpanzee    5.68%    passed     39.39%
#    3  Rhesus        5.78%    passed     15.40%
#    4  Mouse         9.07%    failed      0.00%
# ****  TOTAL         6.56%  1 sequences failed composition chi2 test (p-value<5%; df=3)
# ...

# %%
tree.to_rich_dict()
# Out:
# {'newick': '(Human,Chimpanzee,(Rhesus,Mouse)edge.0)',
#  'edge_attributes': {'Human': {'length': 0.0063211201,
#    'A/C': 1.0,
#    'A/G': 3.82025079,
#    'A/T': 1.0,
#    'C/G': 1.0,
#    'C/T': 3.82025079,
#    'G/T': 1.0},
#   'Chimpanzee': {'length': 0.002967578,
#    'A/C': 1.0,
#    'A/G': 3.82025079,
#    'A/T': 1.0,
#    'C/G': 1.0,
#    'C/T': 3.82025079,
#    'G/T': 1.0},
#   'Rhesus': {'length': 0.0228519739,
#    'A/C': 1.0,
#    'A/G': 3.82025079,
#    'A/T': 1.0,
#    'C/G': 1.0,
#    'C/T': 3.82025079,
#    'G/T': 1.0},
#   'Mouse': {'length': 0.3072009029,
#    'A/C': 1.0,
#    'A/G': 3.82025079,
#    'A/T': 1.0,
#    'C/G': 1.0,
#    'C/T': 3.82025079,
#    'G/T': 1.0},
#   'edge.0': {'length': 0.01373649616,
#    'A/C': 1.0,
#    'A/G': 3.82025079,
#    'A/T': 1.0,
#    'C/G': 1.0,
#    'C/T': 3.82025079,
#    'G/T': 1.0},
#   'root': {'length': None, 'lnL': -6736.94578464}},
#  'type': 'cogent3.core.tree.PhyloNode',
#  'version': '2024.5.7a1'}
